# %% [markdown]
# # D2(c) — Dependency-Aware Parallel Tool Calls\n\nThis English-only submission notebook demonstrates the D2(c) extension. The runner accepts a set of tool calls per turn, executes every call, records every observation, and uses an explicit policy so only independent reads can run together.\n\nThe controlled comparison is a baseline. D4 must repeat it on the full evaluation set before the team claims unchanged pass rate.\n

# %%
from pathlib import Path\nimport subprocess\nREPOSITORY = Path.cwd()\nsubprocess.run(['python3', 'scripts/run_d2c_comparison.py'], cwd=REPOSITORY, check=True)\n

# %% [markdown]
# ## Verification\n\nRun all unit tests, including dependency-policy and multi-action trace-order tests.\n

# %%
subprocess.run(['python3', '-m', 'unittest', 'discover', '-s', 'tests', '-v'], cwd=REPOSITORY, check=True)\n
