# %% [markdown]
# # D0 — Evidence Before Agent Code
#
# This notebook documents the D0 pre-build phase for PE6201 Problem B. It does not implement an agent, routing policy, model call, or booking action.
#
# Run the profiler below to verify that the fixture records are connected before agent implementation begins.

# %% [markdown]
# ## What this check proves
#
# The profiler verifies that each referral resolves to its specialty, patient, and contact records. It is an evidence-map check only: routing, labels, booking, and model calls remain out of scope until the D0 commit exists.

# %%
from pathlib import Path
import subprocess

repository = Path.cwd()
result = subprocess.run(["python3", "scripts/d0_data_profile.py"], cwd=repository, text=True, capture_output=True, check=True)
print(result.stdout)

# %% [markdown]
# ## Next decision
#
# After this notebook and the D0 documents are committed, proceed to D1 and D2. Keep future sessions self-explanatory: begin each logical block with a concise English markdown cell stating its purpose, inputs, outputs, and safety boundary.
