# %% [markdown]
# # D2(a) — Tool Set Rationale
#
# This notebook introduces the English D2(a) design document for Problem B. The objective is to justify a minimal, distinguishable, and safe tool set before writing D2(b) descriptors. The current document is explicit about which claims still require D4 removal-test evidence.

# %%
from pathlib import Path
repo = Path.cwd()
print((repo / 'docs' / 'D2_tool_set.md').read_text(encoding='utf-8'))

# %% [markdown]
# ## Review checklist
#
# For every retained tool, verify: (1) a named task fails without it, (2) its boundary is distinguishable from its neighbours, and (3) its prompt, safety, and write-action cost is justified. Run D4 removal tests before treating the design baseline as final evidence.
