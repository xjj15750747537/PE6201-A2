# %% [markdown]
# # D4-D6 Owner Workbook\n\nThis submission notebook is English-only. It creates easy-to-edit templates for D4, D5, and D6. Do not report final numbers until D3 is integrated and the full evaluation set is rerun from clean state.\n

# %%
from pathlib import Path\nimport subprocess\nREPOSITORY = Path.cwd()\nsubprocess.run(['python3', 'scripts/prepare_d4_d6_workspace.py'], cwd=REPOSITORY, check=True)\n

# %% [markdown]
# ## Owner checklist\n\nOpen `docs/D4_D6_owner_playbook.md` and complete the template files in `templates/`. The D4 labels, D5 model assignments, and D6 measurements are team-owned inputs; the notebook never invents them.\n

# %%
print((REPOSITORY / 'docs' / 'D4_D6_owner_playbook.md').read_text(encoding='utf-8'))\n
